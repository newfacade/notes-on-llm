# %% [markdown]
# # Contents
#
#
# basic
# - attention
# - gpt
# - gpt2
# - gpt3
# - instruct gpt
# - codex
# - tokenize
# - gpt2 from scratch
#
# technique
# - rope
# - swish
# - flash attention
# - lora
#
# models
# - llama
# - llama2
# - code llama
# - llama3
# - deepseek
# - deepseek coder
# - deepseek v2
# - deepseek v2 coder
# - qwen
# - qwen2
# - qwen2.5 coder
# - phi4
#
# eval
# - mbpp
# - livecodebench
# - GSM8k
# - reward bench
# - alpaca eval
#
# data
# - alpaca
# - codealpaca
# - wizard
# - magic
#
# SFT
# - less is more
# - sft affect
# - alignment good data
# - quantity to quality
# - rejection sampling
# - rft
#
# RM
# - secret
# - rlcd
# - rmboost
# - west-of-n
# - multi
# - ee
# - helpsteer2
# - interlm2
# - skywork reward
# - reward weak sup
# - critique gpt
#
# preference optimization
# - ppo
# - secret
# - dpo
# - dpop
# - rso
# - kto
# - grpo
# - gold
# - online-offline
# - unpacking
#
# o1
# - cot
# - step by step
# - self correct rl
