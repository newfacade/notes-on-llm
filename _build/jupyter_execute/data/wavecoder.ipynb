# %% [markdown]
# # WaveCoder
#
# ```{note}
# To
# enable the models to tackle complex coderelated
# tasks, we propose a method to stably
# generate diverse, high-quality instruction
# data <span style="color: red">from open source code dataset</span> in multitask
# scenarios and obtain CodeSeaXDataset.
# ```
#
# ```{figure} ../images/wave1.png
# ```
