# %% [markdown]
# # Contents
#
#
# base
# - attention
# - gpt
# - instruct-gpt
#
# models
# - llama3
# - deepseek-v2
# - deepseek-coder-v2
# - deepseek-v3
# - qwen2.5
# - qwen2.5-coder
#
# techniques
# - tokenize
# - rope
# - extending
# - flash attention
# - lora
# - mla
# - deepseek-moe
#
# eval
# - humaneval
# - mbpp
# - evalplus
# - livecodebench
# - crux
# - leetcode-dataset
#
# data
# - alpaca
# - codealpaca
# - wizard
# - magic
# - opencoder
# - taco
#
# sft
# - open-r1 sft code
# - less is more
# - rejection sampling
# - pre-sft
# - attention-cracking
#
# preference
# - secret-of-rlhf1
# - secret-of-rlhf2
# - rlaif-1
# - rlaif-2
# - rlcd
# - west-of-n
# - ee
# - judge
# - armo
# - critique gpt
# - self-reward
# - self-taught
# - reward-xx
# - ppo
# - grpo
# - dpo
# - rso
# - online-offline
# - unpacking
#
# reasoning
# - cot
# - step by step
# - self correct rl
# - yuliang
# - deepseek-r1
# - openr1
